# %%
import os

import glob

from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient

from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry

from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient

ENDPOINT="https://southcentralus.api.cognitive.microsoft.com"

prediction_key="d86efb21dc6746a28af64c51b6ead810"

training_key="b8d0a205e9ff4640885483a260e27121"

# Now there is a trained endpoint that can be used to make a prediction

predictor = CustomVisionPredictionClient(prediction_key, endpoint=ENDPOINT)

trainer = CustomVisionTrainingClient(training_key, endpoint=ENDPOINT)

empty_slots=[]

occupied_slots=[]

path=r'C:/Users/Administrator/Desktop/new code/data/front_back dataset'

all_files = glob.glob(path + "/*.jpg")

for filename in all_files:

    print(filename)

    with open(os.path.join(path,filename), "rb") as image_contents:

        results = predictor.classify_image("559c6601-98e0-47fc-95d6-4664c81af7c2","Iteration2", image_contents.read())

    # Display the results.

        for prediction in results.predictions:

            print ("\t" + prediction.tag_name + ": {0:.2f}%".format(prediction.probability * 100))

            #if prediction.tag_name=="empty slots":

                #my_empty_slots=(float)(format(prediction.probability*100),'.2f')

                #empty_slots.append(my_empty_slots)

            #if prediction.tag_name=="occupied slots":

                #my_occupied_slots=(float)(format(prediction.probability*100),'.2f')

                #occupied_slots.append(my_occupied_slots)
# Out:
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0805_14.jpg
# 	Back: 99.99%
# 	Front: 0.01%
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0805_15.jpg
# 	Back: 99.99%
# 	Front: 0.01%
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0805_17.jpg
# 	Back: 99.49%
# 	Front: 0.50%
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0805_45.jpg
# 	Front: 99.99%
# 	Back: 0.00%
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0805_8.jpg
# 	Back: 99.99%
# 	Front: 0.00%
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0810_15.jpg
# 	Back: 99.99%
# 	Front: 0.02%
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0810_17.jpg
# 	Back: 99.63%
# 	Front: 0.39%
# C:/Users/Administrator/Desktop/new code/data/front_back dataset\20150703_0810_29.jpg
# 	Front: 72.25%
# 	Back: 12.07%
# ...
